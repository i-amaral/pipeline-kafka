# %% [markdown]
# Importar as Bibliotecas

# %%
import pandas as pd
pd.set_option('display.max_colwidth', 150)
pd.set_option('display.min_rows', 20)

from sqlalchemy import create_engine, Date
from datetime import datetime, timedelta
import time

# %% [markdown]
# Definir função para buscar os Dados

# %%
def busca_titulos_tesouro_direto():
    url = 'https://www.tesourotransparente.gov.br/ckan/dataset/df56aa42-484a-4a59-8184-7676580c81e3/resource/796d2059-14e9-44e3-80c9-2d9e30b405c1/download/PrecoTaxaTesouroDireto.csv'
    df = pd.read_csv(url, sep=';', decimal=',')

    df['Data_Vencimento'] = pd.to_datetime(df['Data Vencimento'], dayfirst=True)
    df['Data_Base'] = pd.to_datetime(df['Data Base'], dayfirst=True)

    df = df.set_index(['Tipo Titulo', 'Data Vencimento', 'Data Base'])

    return df

# %% [markdown]
# Busca os títulos do Tesouro Direto

# %%
titulos = busca_titulos_tesouro_direto()

# %%
titulos
# Out:
#                                                                    Taxa Compra Manha  \
# Tipo Titulo                            Data Vencimento Data Base
# Tesouro IGPM+ com Juros Semestrais     01/04/2021      26/10/2007               6.81
#                                        01/07/2017      26/10/2007               7.17
#                                        01/03/2011      26/10/2007               7.31
#                                        01/04/2008      26/10/2007               6.11
# Tesouro Prefixado com Juros Semestrais 01/07/2010      26/10/2007              11.90
#                                        01/01/2010      26/10/2007              11.78
#                                        01/01/2008      26/10/2007              11.16
#                                        01/01/2011      26/10/2007              11.93
#                                        01/01/2012      26/10/2007              11.92
# ...

# %% [markdown]
# Busca somente os Préfixados

# %%
prefixado = titulos.loc[('Tesouro Prefixado')]
prefixado['Tipo'] = 'PRE-FIXADOS'

# %%
prefixado
# Out:
#                             Taxa Compra Manha  Taxa Venda Manha  \
# Data Vencimento Data Base
# 01/07/2008      25/10/2007              11.34             11.38
# 01/01/2008      25/10/2007              11.16             11.19
# 01/01/2009      25/10/2007              11.54             11.58
# 01/07/2009      25/10/2007              11.73             11.78
# 01/10/2009      25/10/2007              11.77             11.82
# 01/01/2010      25/10/2007              11.77             11.83
# 01/10/2008      25/10/2007              11.45             11.49
# 01/04/2008      25/10/2007              11.23             11.26
# 01/10/2009      24/10/2007              11.66             11.71
# 01/07/2009      24/10/2007              11.61             11.66
# ...                                       ...               ...
# 01/01/2014      17/08/2011              11.97             12.03
# 01/01/2015      17/08/2011              12.02             12.08
# ...

# %%
for i, row in prefixado.iterrows():
    ifor_val = datetime.now() - timedelta(hours=2, minutes=0)
    prefixado.at[i,'dt_update'] = ifor_val

# %%
prefixado
# Out:
#                             Taxa Compra Manha  Taxa Venda Manha  \
# Data Vencimento Data Base
# 01/07/2008      25/10/2007              11.34             11.38
# 01/01/2008      25/10/2007              11.16             11.19
# 01/01/2009      25/10/2007              11.54             11.58
# 01/07/2009      25/10/2007              11.73             11.78
# 01/10/2009      25/10/2007              11.77             11.82
# 01/01/2010      25/10/2007              11.77             11.83
# 01/10/2008      25/10/2007              11.45             11.49
# 01/04/2008      25/10/2007              11.23             11.26
# 01/10/2009      24/10/2007              11.66             11.71
# 01/07/2009      24/10/2007              11.61             11.66
# ...                                       ...               ...
# 01/01/2014      17/08/2011              11.97             12.03
# 01/01/2015      17/08/2011              12.02             12.08
# ...

# %% [markdown]
# Busca os IPCAs

# %%
ipca = titulos.loc[('Tesouro IPCA+')]
ipca['Tipo'] = 'IPCA'

# %%
for i, row in ipca.iterrows():
    ifor_val = datetime.now() - timedelta(hours=2, minutes=0)
    ipca.at[i,'dt_update'] = ifor_val

# %%
ipca
# Out:
#                             Taxa Compra Manha  Taxa Venda Manha  \
# Data Vencimento Data Base
# 15/08/2024      25/10/2007               6.29              6.37
# 15/05/2015      25/10/2007               7.19              7.25
# 15/08/2024      24/10/2007               6.30              6.38
# 15/05/2015      24/10/2007               7.12              7.18
# 15/08/2024      28/09/2007               6.38              6.46
# 15/05/2015      28/09/2007               6.79              6.85
# 15/08/2024      27/09/2007               6.37              6.45
# 15/05/2015      27/09/2007               6.79              6.85
# 15/08/2024      26/09/2007               6.38              6.46
# 15/05/2015      26/09/2007               6.80              6.86
# ...                                       ...               ...
#                 28/12/2010               6.12              6.16
# 15/05/2035      18/08/2011               6.03              6.13
# ...

# %%
cols_rename = {
    'Data Vencimento': 'DataVencimento',
    'Data Base': 'Data_Base',
    'Taxa Compra Manha': 'CompraManha',
    'Taxa Venda Manha': 'VendaManha',
    'PU Compra Manha': 'PUCompraManha',
    'PU Venda Manha': 'PUVendaManha',
    'PU Base Manha': 'PUBaseManha'
    }

ipca = ipca.rename(columns=cols_rename)
prefixado = prefixado.rename(columns=cols_rename)

# %%
ipca
# Out:
#                             CompraManha  VendaManha  PUCompraManha  \
# Data Vencimento Data Base
# 15/08/2024      25/10/2007         6.29        6.37         601.15
# 15/05/2015      25/10/2007         7.19        7.25         989.75
# 15/08/2024      24/10/2007         6.30        6.38         600.11
# 15/05/2015      24/10/2007         7.12        7.18         994.45
# 15/08/2024      28/09/2007         6.38        6.46         589.33
# 15/05/2015      28/09/2007         6.79        6.85        1011.96
# 15/08/2024      27/09/2007         6.37        6.45         589.98
# 15/05/2015      27/09/2007         6.79        6.85        1011.45
# 15/08/2024      26/09/2007         6.38        6.46         588.85
# 15/05/2015      26/09/2007         6.80        6.86        1010.38
# ...                                 ...         ...            ...
#                 28/12/2010         6.12        6.16        1521.44
# 15/05/2035      18/08/2011         6.03        6.13         515.76
# ...

# %% [markdown]
# Grava os dados no Banco de Dados

# %%
connection_string = 'postgresql://postgres:postgres@localhost:5432/postgres'

# %%
engine = create_engine(connection_string)

# %%
ipca.dtypes
prefixado.dtypes
# Out:
# CompraManha               float64
# VendaManha                float64
# PUCompraManha             float64
# PUVendaManha              float64
# PUBaseManha               float64
# Data_Vencimento    datetime64[us]
# Data_Base          datetime64[us]
# Tipo                          str
# dt_update          datetime64[us]
# dtype: object

# %%
ipca.to_sql('dadostesouroipca', con=engine, if_exists='append', index=False, dtype={'Data_Vencimento': Date(), 'Data_Base': Date()})
prefixado.to_sql('dadostesouropre', con=engine, if_exists='append', index=False, dtype={'Data_Vencimento': Date(), 'Data_Base': Date()})
# Out:
# 805
